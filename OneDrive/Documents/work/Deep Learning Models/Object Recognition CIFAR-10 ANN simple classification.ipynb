# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10

# %%
# Load CIFAR-10 dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# %%
# Select one image (e.g., first image in the dataset)
image = X_train[0]  # Shape: (32, 32, 3)

# %%
# Display the original image
plt.figure(figsize=(10, 4))
plt.subplot(1, 4, 1)
plt.imshow(image)
plt.title("Original Image (RGB)")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(31.5), np.float64(31.5), np.float64(-0.5))

# %%
# Extract RGB channels
red_channel = image[:, :, 0]  # Red channel
green_channel = image[:, :, 1]  # Green channel
blue_channel = image[:, :, 2]  # Blue channel

# %%
# Display individual channels
plt.subplot(1, 4, 2)
plt.imshow(red_channel, cmap="Reds")
plt.title("Red Channel")
plt.axis("off")

plt.show()

# %%
plt.subplot(1, 4, 3)
plt.imshow(green_channel, cmap="Greens")
plt.title("Green Channel")
plt.axis("off")

plt.show()

# %%
plt.subplot(1, 4, 4)
plt.imshow(blue_channel, cmap="Blues")
plt.title("Blue Channel")
plt.axis("off")

plt.show()

# %%
# Flatten the image (32x32x3 → 3072,)
flattened_image = image.flatten()

# %%
# Print shapes
print("Original Shape:", image.shape)  # (32, 32, 3)
print("Flattened Shape:", flattened_image.shape)  # (3072,)
# Out:
# Original Shape: (32, 32, 3)
# Flattened Shape: (3072,)
